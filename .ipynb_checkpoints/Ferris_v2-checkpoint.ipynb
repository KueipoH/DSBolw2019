# %%
import pandas as pd
import dask
import dask.dataframe as dd
import featuretools as ft
import numpy as np
import json
from pandas.io.json import json_normalize

from functools import partial
import gc
import time
from contextlib import contextmanager
import shap

import warnings
import cmath
from tqdm import tqdm
warnings.simplefilter(action='ignore', category=FutureWarning)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-49e4c588e93e> in <module>
#      11 import time
#      12 from contextlib import contextmanager
# ---> 13 import shap
#      14
#      15 import warnings
#
# ModuleNotFoundError: No module named 'shap'

# %%
@contextmanager
def timer(title):
    t0 = time.time()
    yield
    print("{} - done in {:.0f}s".format(title, time.time() - t0))

# %%
col_dtype = {
    'event_id':'object', 'game_session':'object', 'installation_id':'object',
    'event_count':'int16', 'event_code':'category', 'game_time':'int32', 'title':'category', 
    'type':'category', 'world':'category'
}



train = dd.read_csv('/kaggle/input/data-science-bowl-2019/train.csv', 
                    parse_dates=['timestamp'], 
                    dtype=col_dtype,
                    usecols=['event_id', 'game_session', 'timestamp', 'installation_id', 'event_count', 'event_code', 'game_time', 'title', 'type', 'world'])

train_event_data = dd.read_csv('/kaggle/input/data-science-bowl-2019/train.csv', 
                               converters={'event_data': json.loads},
                               usecols=['event_data'])

# Reduce dataset
# installation_id_sample_1000 = dd.read_csv('/kaggle/input/installation-id-sample-1000csv/installation_id_sample_1000.csv', usecols=['installation_id'])
# train = train.merge(installation_id_sample_1000, on='installation_id', how='inner')
# # Reduce dataset

# %%
train_labels_df = dd.read_csv('/kaggle/input/data-science-bowl-2019/train_labels.csv').compute(scheduler='threads')

# %%
test = dd.read_csv('/kaggle/input/data-science-bowl-2019/test.csv', 
                    parse_dates=['timestamp'], 
                    dtype=col_dtype,
                    usecols=['event_id', 'game_session', 'timestamp', 'installation_id', 'event_count', 'event_code', 'game_time', 'title', 'type', 'world'])

# %%
game_sequence = (train
    .drop_duplicates(subset=['game_session'], keep='first')
    [['event_id', 'game_session', 'timestamp', 'installation_id', 'type', 'title', 'world', 'game_time']]
    .reset_index(drop=True)
    #.assign(diff_sec = lambda df: df.groupby('installation_id')['timestamp'].transform(lambda x: x.diff()).dt.total_seconds().fillna(0))
)

game_sequence_y = (game_sequence
    .query('type == "Assessment"')
    #[['event_id', 'game_session', 'timestamp', 'installation_id', 'event_code', 'title', 'type', 'world', 'game_time']]
    .reset_index(drop=True)
    .copy()
)

game_sequence_filter = (game_sequence
    .merge(game_sequence_y, on='installation_id', how='inner', suffixes=('_x', '_y'))
    .assign(diff = lambda df: (df['timestamp_y'] - df['timestamp_x']).dt.total_seconds())
    .query('0 <= diff <10000')
    .reset_index(drop=True)
    [['game_session_x', 'game_session_y', 'title_y', 'world_y', 'game_time_y']]
)#.compute(scheduler='threads')

# %%
def flatten(record, sel_cols):
    return dict(map(lambda x: (x, record.get(x)), sel_cols))

event_data_cols = ['coordinates',
                   'correct', 'duration', 'dwell_time', 'misses', 'round', 'total_duration', 'version']
event_data_cols_meta = {
    'correct': np.bool, 
    'duration': np.float16, 
    'dwell_time': np.float32, 
    'misses': np.float32, 
    'round': np.float16, 
    'total_duration': np.float32, 
    'version': np.float16
}

with timer("Process Event Data"):

    flatten = partial(flatten, sel_cols=event_data_cols)

    event_data = train_event_data['event_data'].to_bag().map(flatten).to_dataframe(meta=event_data_cols_meta)
    train = (dd.concat([train, event_data], axis=1)
        .merge(game_sequence_filter, left_on='game_session', right_on='game_session_x', how='inner')
        .query('game_session_y != game_session')
        .drop(columns=['game_session_x'])
    )
    gc.collect()
# Out:
# /opt/conda/lib/python3.6/site-packages/dask/dataframe/multi.py:1055: UserWarning: Concatenating dataframes with unknown divisions.
# We're assuming that the indexes of each dataframes are
#  aligned. This assumption is not generally safe.
#   "Concatenating dataframes with unknown divisions.\n"

# %%
with timer("Process train_df"):

    train_df = train.compute(scheduler='threads').reset_index(drop=True)
    
    gc.collect()

# %% [markdown]
# ## Version 0.3

# %%
es = ft.EntitySet(id="game_session_y_data")

# %%
es = es.entity_from_dataframe(entity_id="actions",
                              dataframe=train_df,
                              index='action_id',
                              make_index=True)

# %%
es = es.normalize_entity(base_entity_id="actions",
                         new_entity_id="game_sessions",
                         index="game_session",
                         additional_variables=["title", "type", "world", "game_session_y", "title_y", "world_y", "installation_id"])

# %%
es = es.normalize_entity(base_entity_id="game_sessions",
                         new_entity_id="game_session_ys",
                         index="game_session_y",
                         additional_variables=["title_y", "world_y", "installation_id"])

# %%
es = es.normalize_entity(base_entity_id="game_session_ys",
                         new_entity_id="installation_ids",
                         index="installation_id")

# %%
es.plot()

# %%
with timer("Process Feature Matrix"):

    feature_matrix, feature_defs = ft.dfs(entityset=es,
                                      target_entity="game_session_ys")
    gc.collect()

# %%
with timer("Process Train Data DF"):

    train_data_df = (feature_matrix
        .merge(train_labels_df[['game_session', 'accuracy_group']], left_index=True, right_on='game_session', how='inner')
        .drop(columns=['game_session', 'installation_id'])
        .reset_index(drop=True)
        )
    
    gc.collect()

# %%
train_data_df.head()
# Out:
#                         title_y      world_y  COUNT(game_sessions)  \
# 0  Mushroom Sorter (Assessment)  TREETOPCITY                    18
# 1    Bird Measurer (Assessment)  TREETOPCITY                     7
# 2  Mushroom Sorter (Assessment)  TREETOPCITY                     1
# 3  Mushroom Sorter (Assessment)  TREETOPCITY                     1
# 4    Bird Measurer (Assessment)  TREETOPCITY                     9
#
#    NUM_UNIQUE(game_sessions.title)  NUM_UNIQUE(game_sessions.world)  \
# 0                               14                                3
# 1                                7                                1
# 2                                1                                1
# 3                                1                                1
# 4                                7                                1
#
#    NUM_UNIQUE(game_sessions.type)     MODE(game_sessions.title)  \
# 0                               3              All Star Sorting
# 1                               4                      Air Show
# 2                               1    Bird Measurer (Assessment)
# 3                               1  Mushroom Sorter (Assessment)
# 4                               4                 Crystals Rule
#
#   MODE(game_sessions.world) MODE(game_sessions.type)  \
# 0               TREETOPCITY                     Clip
# 1               TREETOPCITY                     Clip
# 2               TREETOPCITY               Assessment
# 3               TREETOPCITY               Assessment
# 4               TREETOPCITY                     Clip
#
#    SUM(actions.total_duration)  ...  installation_ids.MEAN(actions.round)  \
# 0                     878175.0  ...                              3.308594
# 1                     737476.0  ...                              3.308594
# 2                      37560.0  ...                              3.308594
# 3                      17574.0  ...                              3.308594
# 4                     385560.0  ...                              3.308594
#
#    installation_ids.MEAN(actions.game_time)  \
# 0                              95496.416021
# 1                              95496.416021
# 2                              95496.416021
# 3                              95496.416021
# 4                              95496.416021
#
#    installation_ids.MEAN(actions.version)  installation_ids.COUNT(actions)  \
# 0                                     1.0                             4257
# 1                                     1.0                             4257
# 2                                     1.0                             4257
# 3                                     1.0                             4257
# 4                                     1.0                             4257
#
#    installation_ids.PERCENT_TRUE(actions.correct)  \
# 0                                        0.033357
# 1                                        0.033357
# 2                                        0.033357
# 3                                        0.033357
# 4                                        0.033357
#
#    installation_ids.NUM_UNIQUE(actions.event_code)  \
# 0                                               32
# 1                                               32
# 2                                               32
# 3                                               32
# 4                                               32
#
#    installation_ids.NUM_UNIQUE(actions.event_id)  \
# 0                                            120
# 1                                            120
# 2                                            120
# 3                                            120
# 4                                            120
#
#    installation_ids.MODE(actions.event_code)  \
# 0                                       3010
# 1                                       3010
# 2                                       3010
# 3                                       3010
# 4                                       3010
#
#    installation_ids.MODE(actions.event_id)  accuracy_group
# 0                                 5d042115               3
# 1                                 5d042115               0
# 2                                 5d042115               3
# 3                                 5d042115               2
# 4                                 5d042115               3
#
# [5 rows x 456 columns]

# %%
train_data_df['installation_ids.MEAN(actions.game_time)'].describe()
# Out:
# 0         95496.416021
# 1         95496.416021
# 2         95496.416021
# 3         95496.416021
# 4         95496.416021
#              ...
# 17048     87242.761985
# 17049    164981.221847
# 17050     65480.545833
# 17051     65480.545833
# 17052     65480.545833
# Name: installation_ids.MEAN(actions.game_time), Length: 17053, dtype: float64

# %%
train_data_df.columns.tolist()
# Out:
# ['title_y',
#  'world_y',
#  'COUNT(game_sessions)',
#  'NUM_UNIQUE(game_sessions.title)',
#  'NUM_UNIQUE(game_sessions.world)',
#  'NUM_UNIQUE(game_sessions.type)',
#  'MODE(game_sessions.title)',
#  'MODE(game_sessions.world)',
#  'MODE(game_sessions.type)',
#  'SUM(actions.total_duration)',
#  'SUM(actions.misses)',
#  'SUM(actions.event_count)',
#  'SUM(actions.duration)',
#  'SUM(actions.dwell_time)',
#  'SUM(actions.game_time_y)',
#  'SUM(actions.round)',
#  'SUM(actions.game_time)',
#  'SUM(actions.version)',
#  'STD(actions.total_duration)',
#  'STD(actions.misses)',
#  'STD(actions.event_count)',
#  'STD(actions.duration)',
#  'STD(actions.dwell_time)',
#  'STD(actions.game_time_y)',
#  'STD(actions.round)',
#  'STD(actions.game_time)',
#  'STD(actions.version)',
#  'MAX(actions.total_duration)',
#  'MAX(actions.misses)',
#  'MAX(actions.event_count)',
#  'MAX(actions.duration)',
#  'MAX(actions.dwell_time)',
#  'MAX(actions.game_time_y)',
#  'MAX(actions.round)',
#  'MAX(actions.game_time)',
#  'MAX(actions.version)',
#  'SKEW(actions.total_duration)',
#  'SKEW(actions.misses)',
#  'SKEW(actions.event_count)',
#  'SKEW(actions.duration)',
#  'SKEW(actions.dwell_time)',
#  'SKEW(actions.game_time_y)',
#  'SKEW(actions.round)',
#  'SKEW(actions.game_time)',
#  'SKEW(actions.version)',
#  'MIN(actions.total_duration)',
#  'MIN(actions.misses)',
#  'MIN(actions.event_count)',
#  'MIN(actions.duration)',
#  'MIN(actions.dwell_time)',
#  'MIN(actions.game_time_y)',
#  'MIN(actions.round)',
#  'MIN(actions.game_time)',
#  'MIN(actions.version)',
#  'MEAN(actions.total_duration)',
#  'MEAN(actions.misses)',
#  'MEAN(actions.event_count)',
#  'MEAN(actions.duration)',
#  'MEAN(actions.dwell_time)',
#  'MEAN(actions.game_time_y)',
#  'MEAN(actions.round)',
#  'MEAN(actions.game_time)',
#  'MEAN(actions.version)',
#  'COUNT(actions)',
#  'PERCENT_TRUE(actions.correct)',
#  'NUM_UNIQUE(actions.event_code)',
#  'NUM_UNIQUE(actions.event_id)',
#  'MODE(actions.event_code)',
#  'MODE(actions.event_id)',
#  'SUM(game_sessions.STD(actions.version))',
#  'SUM(game_sessions.MIN(actions.version))',
#  'SUM(game_sessions.SKEW(actions.round))',
#  'SUM(game_sessions.STD(actions.misses))',
#  'SUM(game_sessions.MEAN(actions.dwell_time))',
#  'SUM(game_sessions.NUM_UNIQUE(actions.event_id))',
#  'SUM(game_sessions.MIN(actions.event_count))',
#  'SUM(game_sessions.MIN(actions.total_duration))',
#  'SUM(game_sessions.MEAN(actions.game_time))',
#  'SUM(game_sessions.MAX(actions.event_count))',
#  'SUM(game_sessions.SKEW(actions.total_duration))',
#  'SUM(game_sessions.MIN(actions.dwell_time))',
#  'SUM(game_sessions.MEAN(actions.version))',
#  'SUM(game_sessions.STD(actions.event_count))',
#  'SUM(game_sessions.MIN(actions.round))',
#  'SUM(game_sessions.MAX(actions.version))',
#  'SUM(game_sessions.MEAN(actions.game_time_y))',
#  'SUM(game_sessions.STD(actions.dwell_time))',
#  'SUM(game_sessions.SKEW(actions.game_time))',
#  'SUM(game_sessions.MEAN(actions.total_duration))',
#  'SUM(game_sessions.MAX(actions.game_time_y))',
#  'SUM(game_sessions.MEAN(actions.event_count))',
#  'SUM(game_sessions.MIN(actions.misses))',
#  'SUM(game_sessions.MEAN(actions.duration))',
#  'SUM(game_sessions.STD(actions.total_duration))',
#  'SUM(game_sessions.MAX(actions.duration))',
#  'SUM(game_sessions.SKEW(actions.version))',
#  'SUM(game_sessions.MAX(actions.game_time))',
#  'SUM(game_sessions.MIN(actions.game_time))',
#  'SUM(game_sessions.MEAN(actions.round))',
#  'SUM(game_sessions.MAX(actions.misses))',
#  'SUM(game_sessions.NUM_UNIQUE(actions.event_code))',
#  'SUM(game_sessions.MAX(actions.dwell_time))',
#  'SUM(game_sessions.MIN(actions.game_time_y))',
#  'SUM(game_sessions.MEAN(actions.misses))',
#  'SUM(game_sessions.SKEW(actions.event_count))',
#  'SUM(game_sessions.STD(actions.game_time))',
#  'SUM(game_sessions.STD(actions.round))',
#  'SUM(game_sessions.STD(actions.duration))',
#  'SUM(game_sessions.MAX(actions.total_duration))',
#  'SUM(game_sessions.SKEW(actions.duration))',
#  'SUM(game_sessions.SKEW(actions.misses))',
#  'SUM(game_sessions.STD(actions.game_time_y))',
#  'SUM(game_sessions.SKEW(actions.game_time_y))',
#  'SUM(game_sessions.SKEW(actions.dwell_time))',
#  'SUM(game_sessions.MAX(actions.round))',
#  'SUM(game_sessions.MIN(actions.duration))',
#  'SUM(game_sessions.PERCENT_TRUE(actions.correct))',
#  'STD(game_sessions.SUM(actions.round))',
#  'STD(game_sessions.MIN(actions.version))',
#  'STD(game_sessions.SKEW(actions.round))',
#  'STD(game_sessions.MEAN(actions.dwell_time))',
#  'STD(game_sessions.NUM_UNIQUE(actions.event_id))',
#  'STD(game_sessions.MIN(actions.event_count))',
#  'STD(game_sessions.MIN(actions.total_duration))',
#  'STD(game_sessions.MEAN(actions.game_time))',
#  'STD(game_sessions.MAX(actions.event_count))',
#  'STD(game_sessions.SKEW(actions.total_duration))',
#  'STD(game_sessions.SUM(actions.event_count))',
#  'STD(game_sessions.MIN(actions.dwell_time))',
#  'STD(game_sessions.MEAN(actions.version))',
#  'STD(game_sessions.MIN(actions.round))',
#  'STD(game_sessions.MAX(actions.version))',
#  'STD(game_sessions.MEAN(actions.game_time_y))',
#  'STD(game_sessions.SKEW(actions.game_time))',
#  'STD(game_sessions.MEAN(actions.total_duration))',
#  'STD(game_sessions.MAX(actions.game_time_y))',
#  'STD(game_sessions.SUM(actions.total_duration))',
#  'STD(game_sessions.MEAN(actions.event_count))',
#  'STD(game_sessions.MIN(actions.misses))',
#  'STD(game_sessions.MEAN(actions.duration))',
#  'STD(game_sessions.MAX(actions.duration))',
#  'STD(game_sessions.SKEW(actions.version))',
#  'STD(game_sessions.MAX(actions.game_time))',
#  'STD(game_sessions.SUM(actions.version))',
#  'STD(game_sessions.MIN(actions.game_time))',
#  'STD(game_sessions.COUNT(actions))',
#  'STD(game_sessions.MEAN(actions.round))',
#  'STD(game_sessions.MAX(actions.misses))',
#  'STD(game_sessions.NUM_UNIQUE(actions.event_code))',
#  'STD(game_sessions.SUM(actions.game_time))',
#  'STD(game_sessions.SUM(actions.game_time_y))',
#  'STD(game_sessions.SUM(actions.dwell_time))',
#  'STD(game_sessions.MAX(actions.dwell_time))',
#  'STD(game_sessions.MIN(actions.game_time_y))',
#  'STD(game_sessions.MEAN(actions.misses))',
#  'STD(game_sessions.SKEW(actions.event_count))',
#  'STD(game_sessions.MAX(actions.total_duration))',
#  'STD(game_sessions.SKEW(actions.duration))',
#  'STD(game_sessions.SKEW(actions.misses))',
#  'STD(game_sessions.SKEW(actions.game_time_y))',
#  'STD(game_sessions.SUM(actions.duration))',
#  'STD(game_sessions.SKEW(actions.dwell_time))',
#  'STD(game_sessions.MAX(actions.round))',
#  'STD(game_sessions.MIN(actions.duration))',
#  'STD(game_sessions.SUM(actions.misses))',
#  'STD(game_sessions.PERCENT_TRUE(actions.correct))',
#  'MAX(game_sessions.SUM(actions.round))',
#  'MAX(game_sessions.STD(actions.version))',
#  'MAX(game_sessions.MIN(actions.version))',
#  'MAX(game_sessions.SKEW(actions.round))',
#  'MAX(game_sessions.STD(actions.misses))',
#  'MAX(game_sessions.MEAN(actions.dwell_time))',
#  'MAX(game_sessions.NUM_UNIQUE(actions.event_id))',
#  'MAX(game_sessions.MIN(actions.event_count))',
#  'MAX(game_sessions.MIN(actions.total_duration))',
#  'MAX(game_sessions.MEAN(actions.game_time))',
#  'MAX(game_sessions.SKEW(actions.total_duration))',
#  'MAX(game_sessions.SUM(actions.event_count))',
#  'MAX(game_sessions.MIN(actions.dwell_time))',
#  'MAX(game_sessions.MEAN(actions.version))',
#  'MAX(game_sessions.STD(actions.event_count))',
#  'MAX(game_sessions.MIN(actions.round))',
#  'MAX(game_sessions.MEAN(actions.game_time_y))',
#  'MAX(game_sessions.STD(actions.dwell_time))',
#  'MAX(game_sessions.SKEW(actions.game_time))',
#  'MAX(game_sessions.MEAN(actions.total_duration))',
#  'MAX(game_sessions.SUM(actions.total_duration))',
#  'MAX(game_sessions.MEAN(actions.event_count))',
#  'MAX(game_sessions.MIN(actions.misses))',
#  'MAX(game_sessions.MEAN(actions.duration))',
#  'MAX(game_sessions.STD(actions.total_duration))',
#  'MAX(game_sessions.SKEW(actions.version))',
#  'MAX(game_sessions.SUM(actions.version))',
#  'MAX(game_sessions.MIN(actions.game_time))',
#  'MAX(game_sessions.COUNT(actions))',
#  'MAX(game_sessions.MEAN(actions.round))',
#  'MAX(game_sessions.NUM_UNIQUE(actions.event_code))',
#  'MAX(game_sessions.SUM(actions.game_time))',
#  'MAX(game_sessions.SUM(actions.game_time_y))',
#  'MAX(game_sessions.SUM(actions.dwell_time))',
#  'MAX(game_sessions.MIN(actions.game_time_y))',
#  'MAX(game_sessions.MEAN(actions.misses))',
#  'MAX(game_sessions.SKEW(actions.event_count))',
#  'MAX(game_sessions.STD(actions.game_time))',
#  'MAX(game_sessions.STD(actions.round))',
#  'MAX(game_sessions.STD(actions.duration))',
#  'MAX(game_sessions.SKEW(actions.duration))',
#  'MAX(game_sessions.SKEW(actions.misses))',
#  'MAX(game_sessions.STD(actions.game_time_y))',
#  'MAX(game_sessions.SKEW(actions.game_time_y))',
#  'MAX(game_sessions.SUM(actions.duration))',
#  'MAX(game_sessions.SKEW(actions.dwell_time))',
#  'MAX(game_sessions.MIN(actions.duration))',
#  'MAX(game_sessions.SUM(actions.misses))',
#  'MAX(game_sessions.PERCENT_TRUE(actions.correct))',
#  'SKEW(game_sessions.SUM(actions.round))',
#  'SKEW(game_sessions.STD(actions.version))',
#  'SKEW(game_sessions.MIN(actions.version))',
#  'SKEW(game_sessions.STD(actions.misses))',
#  'SKEW(game_sessions.MEAN(actions.dwell_time))',
#  'SKEW(game_sessions.NUM_UNIQUE(actions.event_id))',
#  'SKEW(game_sessions.MIN(actions.event_count))',
#  'SKEW(game_sessions.MIN(actions.total_duration))',
#  'SKEW(game_sessions.MEAN(actions.game_time))',
#  'SKEW(game_sessions.MAX(actions.event_count))',
#  'SKEW(game_sessions.SUM(actions.event_count))',
#  'SKEW(game_sessions.MIN(actions.dwell_time))',
#  'SKEW(game_sessions.MEAN(actions.version))',
#  'SKEW(game_sessions.STD(actions.event_count))',
#  'SKEW(game_sessions.MIN(actions.round))',
#  'SKEW(game_sessions.MAX(actions.version))',
#  'SKEW(game_sessions.MEAN(actions.game_time_y))',
#  'SKEW(game_sessions.STD(actions.dwell_time))',
#  'SKEW(game_sessions.MEAN(actions.total_duration))',
#  'SKEW(game_sessions.MAX(actions.game_time_y))',
#  'SKEW(game_sessions.SUM(actions.total_duration))',
#  'SKEW(game_sessions.MEAN(actions.event_count))',
#  'SKEW(game_sessions.MIN(actions.misses))',
#  'SKEW(game_sessions.MEAN(actions.duration))',
#  'SKEW(game_sessions.STD(actions.total_duration))',
#  'SKEW(game_sessions.MAX(actions.duration))',
#  'SKEW(game_sessions.MAX(actions.game_time))',
#  'SKEW(game_sessions.SUM(actions.version))',
#  'SKEW(game_sessions.MIN(actions.game_time))',
#  'SKEW(game_sessions.COUNT(actions))',
#  'SKEW(game_sessions.MEAN(actions.round))',
#  'SKEW(game_sessions.MAX(actions.misses))',
#  'SKEW(game_sessions.NUM_UNIQUE(actions.event_code))',
#  'SKEW(game_sessions.SUM(actions.game_time))',
#  'SKEW(game_sessions.SUM(actions.game_time_y))',
#  'SKEW(game_sessions.SUM(actions.dwell_time))',
#  'SKEW(game_sessions.MAX(actions.dwell_time))',
#  'SKEW(game_sessions.MIN(actions.game_time_y))',
#  'SKEW(game_sessions.MEAN(actions.misses))',
#  'SKEW(game_sessions.STD(actions.game_time))',
#  'SKEW(game_sessions.STD(actions.round))',
#  'SKEW(game_sessions.STD(actions.duration))',
#  'SKEW(game_sessions.MAX(actions.total_duration))',
#  'SKEW(game_sessions.STD(actions.game_time_y))',
#  'SKEW(game_sessions.SUM(actions.duration))',
#  'SKEW(game_sessions.MAX(actions.round))',
#  'SKEW(game_sessions.MIN(actions.duration))',
#  'SKEW(game_sessions.SUM(actions.misses))',
#  'SKEW(game_sessions.PERCENT_TRUE(actions.correct))',
#  'MIN(game_sessions.SUM(actions.round))',
#  'MIN(game_sessions.STD(actions.version))',
#  'MIN(game_sessions.SKEW(actions.round))',
#  'MIN(game_sessions.STD(actions.misses))',
#  'MIN(game_sessions.MEAN(actions.dwell_time))',
#  'MIN(game_sessions.NUM_UNIQUE(actions.event_id))',
#  'MIN(game_sessions.MEAN(actions.game_time))',
#  'MIN(game_sessions.MAX(actions.event_count))',
#  'MIN(game_sessions.SKEW(actions.total_duration))',
#  'MIN(game_sessions.SUM(actions.event_count))',
#  'MIN(game_sessions.MEAN(actions.version))',
#  'MIN(game_sessions.STD(actions.event_count))',
#  'MIN(game_sessions.MAX(actions.version))',
#  'MIN(game_sessions.MEAN(actions.game_time_y))',
#  'MIN(game_sessions.STD(actions.dwell_time))',
#  'MIN(game_sessions.SKEW(actions.game_time))',
#  'MIN(game_sessions.MEAN(actions.total_duration))',
#  'MIN(game_sessions.MAX(actions.game_time_y))',
#  'MIN(game_sessions.SUM(actions.total_duration))',
#  'MIN(game_sessions.MEAN(actions.event_count))',
#  'MIN(game_sessions.MEAN(actions.duration))',
#  'MIN(game_sessions.STD(actions.total_duration))',
#  'MIN(game_sessions.MAX(actions.duration))',
#  'MIN(game_sessions.SKEW(actions.version))',
#  'MIN(game_sessions.MAX(actions.game_time))',
#  'MIN(game_sessions.SUM(actions.version))',
#  'MIN(game_sessions.COUNT(actions))',
#  'MIN(game_sessions.MEAN(actions.round))',
#  'MIN(game_sessions.MAX(actions.misses))',
#  'MIN(game_sessions.NUM_UNIQUE(actions.event_code))',
#  'MIN(game_sessions.SUM(actions.game_time))',
#  'MIN(game_sessions.SUM(actions.game_time_y))',
#  'MIN(game_sessions.SUM(actions.dwell_time))',
#  'MIN(game_sessions.MAX(actions.dwell_time))',
#  'MIN(game_sessions.MEAN(actions.misses))',
#  'MIN(game_sessions.SKEW(actions.event_count))',
#  'MIN(game_sessions.STD(actions.game_time))',
#  'MIN(game_sessions.STD(actions.round))',
#  'MIN(game_sessions.STD(actions.duration))',
#  'MIN(game_sessions.MAX(actions.total_duration))',
#  'MIN(game_sessions.SKEW(actions.duration))',
#  'MIN(game_sessions.SKEW(actions.misses))',
#  'MIN(game_sessions.STD(actions.game_time_y))',
#  'MIN(game_sessions.SKEW(actions.game_time_y))',
#  'MIN(game_sessions.SUM(actions.duration))',
#  'MIN(game_sessions.SKEW(actions.dwell_time))',
#  'MIN(game_sessions.MAX(actions.round))',
#  'MIN(game_sessions.SUM(actions.misses))',
#  'MIN(game_sessions.PERCENT_TRUE(actions.correct))',
#  'MEAN(game_sessions.SUM(actions.round))',
#  'MEAN(game_sessions.STD(actions.version))',
#  'MEAN(game_sessions.MIN(actions.version))',
#  'MEAN(game_sessions.SKEW(actions.round))',
#  'MEAN(game_sessions.STD(actions.misses))',
#  'MEAN(game_sessions.MEAN(actions.dwell_time))',
#  'MEAN(game_sessions.NUM_UNIQUE(actions.event_id))',
#  'MEAN(game_sessions.MIN(actions.event_count))',
#  'MEAN(game_sessions.MIN(actions.total_duration))',
#  'MEAN(game_sessions.MEAN(actions.game_time))',
#  'MEAN(game_sessions.MAX(actions.event_count))',
#  'MEAN(game_sessions.SKEW(actions.total_duration))',
#  'MEAN(game_sessions.SUM(actions.event_count))',
#  'MEAN(game_sessions.MIN(actions.dwell_time))',
#  'MEAN(game_sessions.MEAN(actions.version))',
#  'MEAN(game_sessions.STD(actions.event_count))',
#  'MEAN(game_sessions.MIN(actions.round))',
#  'MEAN(game_sessions.MAX(actions.version))',
#  'MEAN(game_sessions.MEAN(actions.game_time_y))',
#  'MEAN(game_sessions.STD(actions.dwell_time))',
#  'MEAN(game_sessions.SKEW(actions.game_time))',
#  'MEAN(game_sessions.MEAN(actions.total_duration))',
#  'MEAN(game_sessions.MAX(actions.game_time_y))',
#  'MEAN(game_sessions.SUM(actions.total_duration))',
#  'MEAN(game_sessions.MEAN(actions.event_count))',
#  'MEAN(game_sessions.MIN(actions.misses))',
#  'MEAN(game_sessions.MEAN(actions.duration))',
#  'MEAN(game_sessions.STD(actions.total_duration))',
#  'MEAN(game_sessions.MAX(actions.duration))',
#  'MEAN(game_sessions.SKEW(actions.version))',
#  'MEAN(game_sessions.MAX(actions.game_time))',
#  'MEAN(game_sessions.SUM(actions.version))',
#  'MEAN(game_sessions.MIN(actions.game_time))',
#  'MEAN(game_sessions.COUNT(actions))',
#  'MEAN(game_sessions.MEAN(actions.round))',
#  'MEAN(game_sessions.MAX(actions.misses))',
#  'MEAN(game_sessions.NUM_UNIQUE(actions.event_code))',
#  'MEAN(game_sessions.SUM(actions.game_time))',
#  'MEAN(game_sessions.SUM(actions.game_time_y))',
#  'MEAN(game_sessions.SUM(actions.dwell_time))',
#  'MEAN(game_sessions.MAX(actions.dwell_time))',
#  'MEAN(game_sessions.MIN(actions.game_time_y))',
#  'MEAN(game_sessions.MEAN(actions.misses))',
#  'MEAN(game_sessions.SKEW(actions.event_count))',
#  'MEAN(game_sessions.STD(actions.game_time))',
#  'MEAN(game_sessions.STD(actions.round))',
#  'MEAN(game_sessions.STD(actions.duration))',
#  'MEAN(game_sessions.MAX(actions.total_duration))',
#  'MEAN(game_sessions.SKEW(actions.duration))',
#  'MEAN(game_sessions.SKEW(actions.misses))',
#  'MEAN(game_sessions.STD(actions.game_time_y))',
#  'MEAN(game_sessions.SKEW(actions.game_time_y))',
#  'MEAN(game_sessions.SUM(actions.duration))',
#  'MEAN(game_sessions.SKEW(actions.dwell_time))',
#  'MEAN(game_sessions.MAX(actions.round))',
#  'MEAN(game_sessions.MIN(actions.duration))',
#  'MEAN(game_sessions.SUM(actions.misses))',
#  'MEAN(game_sessions.PERCENT_TRUE(actions.correct))',
#  'NUM_UNIQUE(game_sessions.MODE(actions.event_code))',
#  'NUM_UNIQUE(game_sessions.MODE(actions.event_id))',
#  'MODE(game_sessions.MODE(actions.event_code))',
#  'MODE(game_sessions.MODE(actions.event_id))',
#  'NUM_UNIQUE(actions.game_sessions.world)',
#  'NUM_UNIQUE(actions.game_sessions.game_session_y)',
#  'NUM_UNIQUE(actions.game_sessions.type)',
#  'NUM_UNIQUE(actions.game_sessions.title)',
#  'MODE(actions.game_sessions.world)',
#  'MODE(actions.game_sessions.game_session_y)',
#  'MODE(actions.game_sessions.type)',
#  'MODE(actions.game_sessions.title)',
#  'installation_ids.COUNT(game_session_ys)',
#  'installation_ids.NUM_UNIQUE(game_session_ys.world_y)',
#  'installation_ids.NUM_UNIQUE(game_session_ys.title_y)',
#  'installation_ids.MODE(game_session_ys.world_y)',
#  'installation_ids.MODE(game_session_ys.title_y)',
#  'installation_ids.COUNT(game_sessions)',
#  'installation_ids.NUM_UNIQUE(game_sessions.type)',
#  'installation_ids.NUM_UNIQUE(game_sessions.title)',
#  'installation_ids.NUM_UNIQUE(game_sessions.world)',
#  'installation_ids.MODE(game_sessions.type)',
#  'installation_ids.MODE(game_sessions.title)',
#  'installation_ids.MODE(game_sessions.world)',
#  'installation_ids.SUM(actions.total_duration)',
#  'installation_ids.SUM(actions.misses)',
#  'installation_ids.SUM(actions.event_count)',
#  'installation_ids.SUM(actions.duration)',
#  'installation_ids.SUM(actions.dwell_time)',
#  'installation_ids.SUM(actions.game_time_y)',
#  'installation_ids.SUM(actions.round)',
#  'installation_ids.SUM(actions.game_time)',
#  'installation_ids.SUM(actions.version)',
#  'installation_ids.STD(actions.total_duration)',
#  'installation_ids.STD(actions.misses)',
#  'installation_ids.STD(actions.event_count)',
#  'installation_ids.STD(actions.duration)',
#  'installation_ids.STD(actions.dwell_time)',
#  'installation_ids.STD(actions.game_time_y)',
#  'installation_ids.STD(actions.round)',
#  'installation_ids.STD(actions.game_time)',
#  'installation_ids.STD(actions.version)',
#  'installation_ids.MAX(actions.total_duration)',
#  'installation_ids.MAX(actions.misses)',
#  'installation_ids.MAX(actions.event_count)',
#  'installation_ids.MAX(actions.duration)',
#  'installation_ids.MAX(actions.dwell_time)',
#  'installation_ids.MAX(actions.game_time_y)',
#  'installation_ids.MAX(actions.round)',
#  'installation_ids.MAX(actions.game_time)',
#  'installation_ids.MAX(actions.version)',
#  'installation_ids.SKEW(actions.total_duration)',
#  'installation_ids.SKEW(actions.misses)',
#  'installation_ids.SKEW(actions.event_count)',
#  'installation_ids.SKEW(actions.duration)',
#  'installation_ids.SKEW(actions.dwell_time)',
#  'installation_ids.SKEW(actions.game_time_y)',
#  'installation_ids.SKEW(actions.round)',
#  'installation_ids.SKEW(actions.game_time)',
#  'installation_ids.SKEW(actions.version)',
#  'installation_ids.MIN(actions.total_duration)',
#  'installation_ids.MIN(actions.misses)',
#  'installation_ids.MIN(actions.event_count)',
#  'installation_ids.MIN(actions.duration)',
#  'installation_ids.MIN(actions.dwell_time)',
#  'installation_ids.MIN(actions.game_time_y)',
#  'installation_ids.MIN(actions.round)',
#  'installation_ids.MIN(actions.game_time)',
#  'installation_ids.MIN(actions.version)',
#  'installation_ids.MEAN(actions.total_duration)',
#  'installation_ids.MEAN(actions.misses)',
#  'installation_ids.MEAN(actions.event_count)',
#  'installation_ids.MEAN(actions.duration)',
#  'installation_ids.MEAN(actions.dwell_time)',
#  'installation_ids.MEAN(actions.game_time_y)',
#  'installation_ids.MEAN(actions.round)',
#  'installation_ids.MEAN(actions.game_time)',
#  'installation_ids.MEAN(actions.version)',
#  'installation_ids.COUNT(actions)',
#  'installation_ids.PERCENT_TRUE(actions.correct)',
#  'installation_ids.NUM_UNIQUE(actions.event_code)',
#  'installation_ids.NUM_UNIQUE(actions.event_id)',
#  'installation_ids.MODE(actions.event_code)',
#  'installation_ids.MODE(actions.event_id)',
#  'accuracy_group']
